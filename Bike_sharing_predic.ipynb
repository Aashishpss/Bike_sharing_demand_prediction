# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Data understanding**

# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv('/content/BoomBikes.csv')
dataset.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        1           1
# 1        2  02-01-2018       1   0     1        0        2           1
# 2        3  03-01-2018       1   0     1        0        3           1
# 3        4  04-01-2018       1   0     1        0        4           1
# 4        5  05-01-2018       1   0     1        0        5           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
dataset.shape
# Out:
# (730, 16)

# %%
dataset.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.995890
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.000339
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.690411    1.394521   20.319259   23.726322   62.765175   12.763620
# std      0.462641    0.544807    7.506729    8.150308   14.237589    5.195841
# min      0.000000    1.000000    2.424346    3.953480    0.000000    1.500244
# 25%      0.000000    1.000000   13.811885   16.889713   52.000000    9.041650
# 50%      1.000000    1.000000   20.465826   24.368225   62.625000   12.125325
# 75%      1.000000    2.000000   26.880615   30.445775   72.989575   15.625589
# max      1.000000    3.000000   35.328347   42.044800   97.250000   34.000021
#
#             casual   registered          cnt
# count   730.000000   730.000000   730.000000
# mean    849.249315  3658.757534  4508.006849
# std     686.479875  1559.758728  1936.011647
# min       2.000000    20.000000    22.000000
# 25%     316.250000  2502.250000  3169.750000
# 50%     717.000000  3664.500000  4548.500000
# 75%    1096.500000  4783.250000  5966.000000
# max    3410.000000  6946.000000  8714.000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
# Assingning different values to diff season

dataset["season"]=dataset["season"].map({1:"spring",2:"summer",3:"fall",4:" winter"})
dataset
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  01-01-2018  spring   0     1        0        1           1
# 1          2  02-01-2018  spring   0     1        0        2           1
# 2          3  03-01-2018  spring   0     1        0        3           1
# 3          4  04-01-2018  spring   0     1        0        4           1
# 4          5  05-01-2018  spring   0     1        0        5           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 725      726  27-12-2019  spring   1    12        0        5           1
# 726      727  28-12-2019  spring   1    12        0        6           0
# 727      728  29-12-2019  spring   1    12        0        0           0
# 728      729  30-12-2019  spring   1    12        0        1           1
# 729      730  31-12-2019  spring   1    12        0        2           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0             2  14.110847  18.18125  80.5833  10.749882     331         654
# 1             2  14.902598  17.68695  69.6087  16.652113     131         670
# 2             1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3             1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4             1   9.305237  11.46350  43.6957  12.522300      82        1518
# ..          ...        ...       ...      ...        ...     ...         ...
# 725           2  10.420847  11.33210  65.2917  23.458911     247        1867
# 726           2  10.386653  12.75230  59.0000  10.416557     644        2451
# 727           2  10.386653  12.12000  75.2917   8.333661     159        1182
# 728           1  10.489153  11.58500  48.3333  23.500518     364        1432
# 729           2   8.849153  11.17435  57.7500  10.374682     439        2290
#
#       cnt
# 0     985
# 1     801
# 2    1349
# 3    1562
# 4    1600
# ..    ...
# 725  2114
# 726  3095
# 727  1341
# 728  1796
# 729  2729
#
# [730 rows x 16 columns]

# %%
dataset["season"].astype("category").value_counts()
# Out:
# season
# fall       188
# summer     184
# spring     180
#  winter    178
# Name: count, dtype: int64

# %%
# 0-->2018 , 1-->2019
dataset["yr"].astype("category").value_counts()
# Out:
# yr
# 0    365
# 1    365
# Name: count, dtype: int64

# %%
dataset["mnth"]=dataset["mnth"].map({1:"Jan",2:"Feb",3:"Mar",4:" Apr",5:"May",6:"Jun",7:"Jul",8:"Aug",9:"Sep",10:"Oct",11:"Novem",12:"Dec"})
dataset
# Out:
#      instant      dteday  season  yr mnth  holiday  weekday  workingday  \
# 0          1  01-01-2018  spring   0  Jan        0        1           1
# 1          2  02-01-2018  spring   0  Jan        0        2           1
# 2          3  03-01-2018  spring   0  Jan        0        3           1
# 3          4  04-01-2018  spring   0  Jan        0        4           1
# 4          5  05-01-2018  spring   0  Jan        0        5           1
# ..       ...         ...     ...  ..  ...      ...      ...         ...
# 725      726  27-12-2019  spring   1  Dec        0        5           1
# 726      727  28-12-2019  spring   1  Dec        0        6           0
# 727      728  29-12-2019  spring   1  Dec        0        0           0
# 728      729  30-12-2019  spring   1  Dec        0        1           1
# 729      730  31-12-2019  spring   1  Dec        0        2           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0             2  14.110847  18.18125  80.5833  10.749882     331         654
# 1             2  14.902598  17.68695  69.6087  16.652113     131         670
# 2             1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3             1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4             1   9.305237  11.46350  43.6957  12.522300      82        1518
# ..          ...        ...       ...      ...        ...     ...         ...
# 725           2  10.420847  11.33210  65.2917  23.458911     247        1867
# 726           2  10.386653  12.75230  59.0000  10.416557     644        2451
# 727           2  10.386653  12.12000  75.2917   8.333661     159        1182
# 728           1  10.489153  11.58500  48.3333  23.500518     364        1432
# 729           2   8.849153  11.17435  57.7500  10.374682     439        2290
#
#       cnt
# 0     985
# 1     801
# 2    1349
# 3    1562
# 4    1600
# ..    ...
# 725  2114
# 726  3095
# 727  1341
# 728  1796
# 729  2729
#
# [730 rows x 16 columns]

# %%
dataset["mnth"].astype("category").value_counts()
# Out:
# mnth
# Aug      62
# Dec      62
# Jan      62
# Jul      62
# Mar      62
# May      62
# Oct      62
#  Apr     60
# Jun      60
# Novem    60
# Sep      60
# Feb      56
# Name: count, dtype: int64

# %%
dataset["holiday"].astype("category").value_counts()
# Out:
# holiday
# 0    709
# 1     21
# Name: count, dtype: int64

# %%
dataset["weekday"]=dataset["weekday"].map({1:"Mon",2:"Tues",3:"Wed",4:"Thurs",5:"Fri",6:"Sar",0:"Sun"})
dataset
# Out:
#      instant      dteday  season  yr mnth  holiday weekday  workingday  \
# 0          1  01-01-2018  spring   0  Jan        0     Mon           1
# 1          2  02-01-2018  spring   0  Jan        0    Tues           1
# 2          3  03-01-2018  spring   0  Jan        0     Wed           1
# 3          4  04-01-2018  spring   0  Jan        0   Thurs           1
# 4          5  05-01-2018  spring   0  Jan        0     Fri           1
# ..       ...         ...     ...  ..  ...      ...     ...         ...
# 725      726  27-12-2019  spring   1  Dec        0     Fri           1
# 726      727  28-12-2019  spring   1  Dec        0     Sar           0
# 727      728  29-12-2019  spring   1  Dec        0     Sun           0
# 728      729  30-12-2019  spring   1  Dec        0     Mon           1
# 729      730  31-12-2019  spring   1  Dec        0    Tues           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0             2  14.110847  18.18125  80.5833  10.749882     331         654
# 1             2  14.902598  17.68695  69.6087  16.652113     131         670
# 2             1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3             1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4             1   9.305237  11.46350  43.6957  12.522300      82        1518
# ..          ...        ...       ...      ...        ...     ...         ...
# 725           2  10.420847  11.33210  65.2917  23.458911     247        1867
# 726           2  10.386653  12.75230  59.0000  10.416557     644        2451
# 727           2  10.386653  12.12000  75.2917   8.333661     159        1182
# 728           1  10.489153  11.58500  48.3333  23.500518     364        1432
# 729           2   8.849153  11.17435  57.7500  10.374682     439        2290
#
#       cnt
# 0     985
# 1     801
# 2    1349
# 3    1562
# 4    1600
# ..    ...
# 725  2114
# 726  3095
# 727  1341
# 728  1796
# 729  2729
#
# [730 rows x 16 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    object
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    object
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    object
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(8), object(4)
# memory usage: 91.4+ KB

# %%
dataset["weekday"].astype("category").value_counts()
# Out:
# weekday
# Mon      105
# Tues     105
# Fri      104
# Sar      104
# Sun      104
# Thurs    104
# Wed      104
# Name: count, dtype: int64

# %%
dataset["workingday"].astype("category").value_counts()
# Out:
# workingday
# 1    504
# 0    226
# Name: count, dtype: int64

# %%
dataset["weathersit"]=dataset["weathersit"].map({1:"A",2:"B",3:"C"})
dataset["weathersit"].astype("category").value_counts()
# Out:
# weathersit
# A    463
# B    246
# C     21
# Name: count, dtype: int64

# %% [markdown]
# ***Data Visualisation***

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(dataset['temp'])
# Out:
# <Axes: xlabel='temp', ylabel='Density'>

# %%
sns.distplot(dataset['atemp'])
plt.show()

# %%
sns.distplot(dataset['windspeed'])
# Out:
# <Axes: xlabel='windspeed', ylabel='Density'>

# %%
# target variable : total rental bikes
sns.distplot(dataset['cnt'])
# Out:
# <Axes: xlabel='cnt', ylabel='Density'>

# %%
# converting date to date and time format
dataset['dteday'] = pd.to_datetime(dataset['dteday'], format='%d-%m-%Y')

# %%
dataset_categorical= dataset.select_dtypes(exclude=['float64','datetime64','int64'])

# %%
dataset_categorical.columns
# Out:
# Index(['season', 'mnth', 'weekday', 'weathersit'], dtype='object')

# %%
plt.figure(figsize=(20,20))
plt.subplot(3,3,1)
sns.boxplot(x='season',y='cnt',data=dataset)
plt.subplot(3,3,2)
sns.boxplot(x='mnth',y='cnt',data=dataset)
plt.subplot(3,3,3)
sns.boxplot(x='weekday',y='cnt',data=dataset)
plt.subplot(3,3,4)
sns.boxplot(x='weathersit',y='cnt',data=dataset)
plt.subplot(3,3,5)
sns.boxplot(x='workingday',y='cnt',data=dataset)
plt.subplot(3,3,6)
sns.boxplot(x='yr',y='cnt',data=dataset)
plt.subplot(3,3,7)
sns.boxplot(x='holiday',y='cnt',data=dataset)
plt.show()

# %%
list=["casual","registered","cnt"]
for i in list:
  dataset[i]=dataset[i].astype("float")

# %%
dataset_numeric= dataset.select_dtypes(include=['float64'])
dataset_numeric.head()
# Out:
#         temp     atemp      hum  windspeed  casual  registered     cnt
# 0  14.110847  18.18125  80.5833  10.749882   331.0       654.0   985.0
# 1  14.902598  17.68695  69.6087  16.652113   131.0       670.0   801.0
# 2   8.050924   9.47025  43.7273  16.636703   120.0      1229.0  1349.0
# 3   8.200000  10.60610  59.0435  10.739832   108.0      1454.0  1562.0
# 4   9.305237  11.46350  43.6957  12.522300    82.0      1518.0  1600.0

# %%
sns.pairplot(dataset_numeric)
plt.show()

# %%
cor=dataset_numeric.corr()
cor
# Out:
#                 temp     atemp       hum  windspeed    casual  registered  \
# temp        1.000000  0.991696  0.128565  -0.158186  0.542731    0.539436
# atemp       0.991696  1.000000  0.141512  -0.183876  0.543362    0.543678
# hum         0.128565  0.141512  1.000000  -0.248506 -0.075211   -0.089212
# windspeed  -0.158186 -0.183876 -0.248506   1.000000 -0.167995   -0.217914
# casual      0.542731  0.543362 -0.075211  -0.167995  1.000000    0.394137
# registered  0.539436  0.543678 -0.089212  -0.217914  0.394137    1.000000
# cnt         0.627044  0.630685 -0.098543  -0.235132  0.672123    0.945411
#
#                  cnt
# temp        0.627044
# atemp       0.630685
# hum        -0.098543
# windspeed  -0.235132
# casual      0.672123
# registered  0.945411
# cnt         1.000000

# %%
mask=np.array(cor)
mask[np.tril_indices_from(mask)]= False
fig,ax=plt.subplots()
fig.set_size_inches(10,10)
sns.heatmap(cor,mask=mask,vmax=1,square= True, annot= True)
# Out:
# <Axes: >

# %%
# removing atmep as it is highly correlated with temp
dataset.drop('atemp',axis=1,inplace=True)
dataset.head()
# Out:
#    instant     dteday  season  yr mnth  holiday weekday  workingday  \
# 0        1 2018-01-01  spring   0  Jan        0     Mon           1
# 1        2 2018-01-02  spring   0  Jan        0    Tues           1
# 2        3 2018-01-03  spring   0  Jan        0     Wed           1
# 3        4 2018-01-04  spring   0  Jan        0   Thurs           1
# 4        5 2018-01-05  spring   0  Jan        0     Fri           1
#
#   weathersit       temp      hum  windspeed  casual  registered     cnt
# 0          B  14.110847  80.5833  10.749882   331.0       654.0   985.0
# 1          B  14.902598  69.6087  16.652113   131.0       670.0   801.0
# 2          A   8.050924  43.7273  16.636703   120.0      1229.0  1349.0
# 3          A   8.200000  59.0435  10.739832   108.0      1454.0  1562.0
# 4          A   9.305237  43.6957  12.522300    82.0      1518.0  1600.0

# %% [markdown]
# # Data Preparation

# %%
dataset_categorical= dataset.select_dtypes(include=["object"])
dataset_categorical.head()
# Out:
#    season mnth weekday weathersit
# 0  spring  Jan     Mon          B
# 1  spring  Jan    Tues          B
# 2  spring  Jan     Wed          A
# 3  spring  Jan   Thurs          A
# 4  spring  Jan     Fri          A

# %%
dataset_dumies= pd.get_dummies(dataset_categorical,drop_first= True)
dataset_dumies.head()
# Out:
#    season_fall  season_spring  season_summer  mnth_Aug  mnth_Dec  mnth_Feb  \
# 0        False           True          False     False     False     False
# 1        False           True          False     False     False     False
# 2        False           True          False     False     False     False
# 3        False           True          False     False     False     False
# 4        False           True          False     False     False     False
#
#    mnth_Jan  mnth_Jul  mnth_Jun  mnth_Mar  ...  mnth_Oct  mnth_Sep  \
# 0      True     False     False     False  ...     False     False
# 1      True     False     False     False  ...     False     False
# 2      True     False     False     False  ...     False     False
# 3      True     False     False     False  ...     False     False
# 4      True     False     False     False  ...     False     False
#
#    weekday_Mon  weekday_Sar  weekday_Sun  weekday_Thurs  weekday_Tues  \
# 0         True        False        False          False         False
# 1        False        False        False          False          True
# 2        False        False        False          False         False
# 3        False        False        False           True         False
# 4        False        False        False          False         False
#
#    weekday_Wed  weathersit_B  weathersit_C
# 0        False          True         False
# 1        False          True         False
# 2         True         False         False
# 3        False         False         False
# 4        False         False         False
#
# [5 rows x 22 columns]

# %%
# drop categorical variables column
dataset= dataset.drop((dataset_categorical.columns),axis=1)
dataset
# Out:
#      instant     dteday  yr  holiday  workingday       temp      hum  \
# 0          1 2018-01-01   0        0           1  14.110847  80.5833
# 1          2 2018-01-02   0        0           1  14.902598  69.6087
# 2          3 2018-01-03   0        0           1   8.050924  43.7273
# 3          4 2018-01-04   0        0           1   8.200000  59.0435
# 4          5 2018-01-05   0        0           1   9.305237  43.6957
# ..       ...        ...  ..      ...         ...        ...      ...
# 725      726 2019-12-27   1        0           1  10.420847  65.2917
# 726      727 2019-12-28   1        0           0  10.386653  59.0000
# 727      728 2019-12-29   1        0           0  10.386653  75.2917
# 728      729 2019-12-30   1        0           1  10.489153  48.3333
# 729      730 2019-12-31   1        0           1   8.849153  57.7500
#
#      windspeed  casual  registered     cnt
# 0    10.749882   331.0       654.0   985.0
# 1    16.652113   131.0       670.0   801.0
# 2    16.636703   120.0      1229.0  1349.0
# 3    10.739832   108.0      1454.0  1562.0
# 4    12.522300    82.0      1518.0  1600.0
# ..         ...     ...         ...     ...
# 725  23.458911   247.0      1867.0  2114.0
# 726  10.416557   644.0      2451.0  3095.0
# 727   8.333661   159.0      1182.0  1341.0
# 728  23.500518   364.0      1432.0  1796.0
# 729  10.374682   439.0      2290.0  2729.0
#
# [730 rows x 11 columns]

# %%
# concatenate dummies variables with the dataset
dataset=pd.concat([dataset,dataset_dumies],axis=1)
dataset.head()
# Out:
#    instant     dteday  yr  holiday  workingday       temp      hum  windspeed  \
# 0        1 2018-01-01   0        0           1  14.110847  80.5833  10.749882
# 1        2 2018-01-02   0        0           1  14.902598  69.6087  16.652113
# 2        3 2018-01-03   0        0           1   8.050924  43.7273  16.636703
# 3        4 2018-01-04   0        0           1   8.200000  59.0435  10.739832
# 4        5 2018-01-05   0        0           1   9.305237  43.6957  12.522300
#
#    casual  registered  ...  mnth_Oct  mnth_Sep  weekday_Mon  weekday_Sar  \
# 0   331.0       654.0  ...     False     False         True        False
# 1   131.0       670.0  ...     False     False        False        False
# 2   120.0      1229.0  ...     False     False        False        False
# 3   108.0      1454.0  ...     False     False        False        False
# 4    82.0      1518.0  ...     False     False        False        False
#
#    weekday_Sun  weekday_Thurs  weekday_Tues  weekday_Wed  weathersit_B  \
# 0        False          False         False        False          True
# 1        False          False          True        False          True
# 2        False          False         False         True         False
# 3        False           True         False        False         False
# 4        False          False         False        False         False
#
#    weathersit_C
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#
# [5 rows x 33 columns]

# %%
dataset= dataset.drop(['instant','dteday'],axis=1,inplace=False)
dataset.head()
# Out:
#    yr  holiday  workingday       temp      hum  windspeed  casual  registered  \
# 0   0        0           1  14.110847  80.5833  10.749882   331.0       654.0
# 1   0        0           1  14.902598  69.6087  16.652113   131.0       670.0
# 2   0        0           1   8.050924  43.7273  16.636703   120.0      1229.0
# 3   0        0           1   8.200000  59.0435  10.739832   108.0      1454.0
# 4   0        0           1   9.305237  43.6957  12.522300    82.0      1518.0
#
#       cnt  season_fall  ...  mnth_Oct  mnth_Sep  weekday_Mon  weekday_Sar  \
# 0   985.0        False  ...     False     False         True        False
# 1   801.0        False  ...     False     False        False        False
# 2  1349.0        False  ...     False     False        False        False
# 3  1562.0        False  ...     False     False        False        False
# 4  1600.0        False  ...     False     False        False        False
#
#    weekday_Sun  weekday_Thurs  weekday_Tues  weekday_Wed  weathersit_B  \
# 0        False          False         False        False          True
# 1        False          False          True        False          True
# 2        False          False         False         True         False
# 3        False           True         False        False         False
# 4        False          False         False        False         False
#
#    weathersit_C
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#
# [5 rows x 31 columns]

# %%
li = ["season_fall", "  season_spring  ", "  season_summer", "mnth_Aug ", "  mnth_Dec ", " mnth_Feb", "  mnth_Jan ", "  mnth_Jul  ", " mnth_Jun  ", "  mnth_Mar  ", "mnth_May ", "mnth_Novem ", "mnth_Oct", " mnth_Sep", "weekday_Mon", "weekday_Sar", "weekday_Sun", " weekday_Thurs", "weekday_Tues", "weekday_Wed", "weathersit_B ", "weathersit_C  "]

for i in li:
    column_name = i.strip()  # Remove leading and trailing whitespaces
    if column_name in dataset.columns:
        dataset[column_name] = dataset[column_name].astype("int")
    else:
        print(f"Column '{column_name}' not found in the dataset.")

# %% [markdown]
# # Building models

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
np.random.seed(0)
df_train,df_test= train_test_split(dataset,train_size=0.7,test_size=0.3,random_state=50)

# %%
scaler=MinMaxScaler()
#applying scaler to all column except dummy variable
va=["temp","hum","windspeed","casual","registered","cnt"]
df_train[va]=scaler.fit_transform(df_train[va])
df_train.describe()
# Out:
#                yr     holiday  workingday        temp         hum   windspeed  \
# count  510.000000  510.000000  510.000000  510.000000  510.000000  510.000000
# mean     0.482353    0.023529    0.698039    0.552680    0.644848    0.318203
# std      0.500179    0.151726    0.459559    0.230600    0.149640    0.167086
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.343347    0.524581    0.197916
# 50%      0.000000    0.000000    1.000000    0.553497    0.648347    0.295422
# 75%      1.000000    0.000000    1.000000    0.757231    0.752576    0.406471
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#            casual  registered         cnt  season_fall  ...    mnth_Oct  \
# count  510.000000  510.000000  510.000000    510.00000  ...  510.000000
# mean     0.249493    0.524432    0.509945      0.24902  ...    0.086275
# std      0.205065    0.227388    0.223408      0.43287  ...    0.281045
# min      0.000000    0.000000    0.000000      0.00000  ...    0.000000
# 25%      0.094179    0.355282    0.350523      0.00000  ...    0.000000
# 50%      0.210149    0.528878    0.516222      0.00000  ...    0.000000
# 75%      0.319186    0.686257    0.672141      0.00000  ...    0.000000
# max      1.000000    1.000000    1.000000      1.00000  ...    1.000000
#
#          mnth_Sep  weekday_Mon  weekday_Sar  weekday_Sun  weekday_Thurs  \
# count  510.000000   510.000000   510.000000   510.000000     510.000000
# mean     0.064706     0.137255     0.149020     0.133333       0.145098
# std      0.246248     0.344454     0.356457     0.340268       0.352545
# min      0.000000     0.000000     0.000000     0.000000       0.000000
# 25%      0.000000     0.000000     0.000000     0.000000       0.000000
# 50%      0.000000     0.000000     0.000000     0.000000       0.000000
# 75%      0.000000     0.000000     0.000000     0.000000       0.000000
# max      1.000000     1.000000     1.000000     1.000000       1.000000
#
#        weekday_Tues  weekday_Wed  weathersit_B  weathersit_C
# count    510.000000   510.000000    510.000000    510.000000
# mean       0.149020     0.149020      0.341176      0.031373
# std        0.356457     0.356457      0.474570      0.174494
# min        0.000000     0.000000      0.000000      0.000000
# 25%        0.000000     0.000000      0.000000      0.000000
# 50%        0.000000     0.000000      0.000000      0.000000
# 75%        0.000000     0.000000      1.000000      0.000000
# max        1.000000     1.000000      1.000000      1.000000
#
# [8 rows x 31 columns]

# %%
plt.figure(figsize=(30,30))
sns.heatmap(df_train.corr(),annot=True,cmap="YlGnBu")
plt.show()

# %%
#dividing ingo x and y
y_train=df_train.pop("cnt")
x_train =df_train.drop(["casual","registered"],axis=1)

x_train.head()
# Out:
#      yr  holiday  workingday      temp       hum  windspeed  season_fall  \
# 707   1        0           1  0.417140  0.933018   0.243629            0
# 172   0        0           1  0.865247  0.729068   0.274549            1
# 14    0        0           1  0.223565  0.513954   0.243603            0
# 204   0        0           1  0.989306  0.567625   0.267859            1
# 182   0        0           1  0.871664  0.458136   0.150755            1
#
#      season_spring  season_summer  mnth_Aug  ...  mnth_Oct  mnth_Sep  \
# 707              0              0         0  ...         0         0
# 172              0              0         0  ...         0         0
# 14               1              0         0  ...         0         0
# 204              0              0         0  ...         0         0
# 182              0              0         0  ...         0         0
#
#      weekday_Mon  weekday_Sar  weekday_Sun  weekday_Thurs  weekday_Tues  \
# 707            1            0            0              0             0
# 172            0            0            0              0             0
# 14             1            0            0              0             0
# 204            0            0            0              0             1
# 182            1            0            0              0             0
#
#      weekday_Wed  weathersit_B  weathersit_C
# 707            0             1             0
# 172            0             0             0
# 14             0             1             0
# 204            0             0             0
# 182            0             0             0
#
# [5 rows x 28 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 31 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   yr             730 non-null    int64
#  1   holiday        730 non-null    int64
#  2   workingday     730 non-null    int64
#  3   temp           730 non-null    float64
#  4   hum            730 non-null    float64
#  5   windspeed      730 non-null    float64
#  6   casual         730 non-null    float64
#  7   registered     730 non-null    float64
#  8   cnt            730 non-null    float64
#  9   season_fall    730 non-null    int64
#  10  season_spring  730 non-null    int64
#  11  season_summer  730 non-null    int64
#  12  mnth_Aug       730 non-null    int64
#  13  mnth_Dec       730 non-null    int64
#  14  mnth_Feb       730 non-null    int64
#  15  mnth_Jan       730 non-null    int64
#  16  mnth_Jul       730 non-null    int64
#  17  mnth_Jun       730 non-null    int64
#  18  mnth_Mar       730 non-null    int64
#  19  mnth_May       730 non-null    int64
#  20  mnth_Novem     730 non-null    int64
#  21  mnth_Oct       730 non-null    int64
#  22  mnth_Sep       730 non-null    int64
#  23  weekday_Mon    730 non-null    int64
#  24  weekday_Sar    730 non-null    int64
#  25  weekday_Sun    730 non-null    int64
#  26  weekday_Thurs  730 non-null    int64
#  27  weekday_Tues   730 non-null    int64
#  28  weekday_Wed    730 non-null    int64
#  29  weathersit_B   730 non-null    int64
#  30  weathersit_C   730 non-null    int64
# dtypes: float64(6), int64(25)
# memory usage: 176.9 KB

# %%
#np.array(x_train)

# %%
import statsmodels.api as sm
x_train_lm= sm.add_constant(x_train)
lr= sm.OLS(y_train,x_train_lm).fit()
lr.params
# Out:
# const            0.592438
# yr               0.232768
# holiday         -0.128894
# workingday      -0.099416
# temp             0.441119
# hum             -0.201396
# windspeed       -0.187316
# season_fall     -0.122197
# season_spring   -0.186477
# season_summer   -0.096319
# mnth_Aug         0.000912
# mnth_Dec        -0.070046
# mnth_Feb        -0.035979
# mnth_Jan        -0.059232
# mnth_Jul        -0.022089
# mnth_Jun         0.020882
# mnth_Mar        -0.001517
# mnth_May         0.027949
# mnth_Novem      -0.073828
# mnth_Oct        -0.014249
# mnth_Sep         0.063373
# weekday_Mon     -0.022845
# weekday_Sar     -0.100575
# weekday_Sun     -0.087194
# weekday_Thurs   -0.005299
# weekday_Tues    -0.035138
# weekday_Wed     -0.020131
# weathersit_B    -0.047443
# weathersit_C    -0.207229
# dtype: float64

# %%
lm =LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm.coef_)
print(lm.intercept_)
# Out:
# [ 0.23276821 -0.12889354 -0.09941629  0.44111932 -0.20139573 -0.187316
#  -0.12219707 -0.18647729 -0.09631855  0.0009119  -0.07004574 -0.03597911
#  -0.05923246 -0.02208921  0.02088207 -0.00151657  0.02794944 -0.07382811
#  -0.01424902  0.06337314 -0.02284537 -0.10057538 -0.08719431 -0.00529893
#  -0.0351375  -0.02013062 -0.04744284 -0.20722948]
# 0.5924382606348109

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.847
# Method:                 Least Squares   F-statistic:                     101.7
# Date:                Sun, 05 May 2024   Prob (F-statistic):          2.29e-182
# Time:                        12:17:04   Log-Likelihood:                 534.58
# No. Observations:                 510   AIC:                            -1011.
# Df Residuals:                     481   BIC:                            -888.4
# Df Model:                          28
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.5924      0.086      6.859      0.000       0.423       0.762
# yr                0.2328      0.008     29.258      0.000       0.217       0.248
# holiday          -0.1289      0.064     -2.020      0.044      -0.254      -0.003
# workingday       -0.0994      0.070     -1.419      0.157      -0.237       0.038
# temp              0.4411      0.046      9.585      0.000       0.351       0.532
# hum              -0.2014      0.039     -5.230      0.000      -0.277      -0.126
# windspeed        -0.1873      0.026     -7.289      0.000      -0.238      -0.137
# season_fall      -0.1222      0.030     -4.131      0.000      -0.180      -0.064
# season_spring    -0.1865      0.025     -7.543      0.000      -0.235      -0.138
# season_summer    -0.0963      0.030     -3.208      0.001      -0.155      -0.037
# mnth_Aug          0.0009      0.033      0.028      0.978      -0.064       0.066
# mnth_Dec         -0.0700      0.034     -2.038      0.042      -0.138      -0.003
# mnth_Feb         -0.0360      0.033     -1.085      0.279      -0.101       0.029
# mnth_Jan         -0.0592      0.035     -1.702      0.089      -0.128       0.009
# mnth_Jul         -0.0221      0.034     -0.649      0.517      -0.089       0.045
# mnth_Jun          0.0209      0.024      0.863      0.388      -0.027       0.068
# mnth_Mar         -0.0015      0.026     -0.059      0.953      -0.052       0.049
# mnth_May          0.0279      0.020      1.390      0.165      -0.012       0.067
# mnth_Novem       -0.0738      0.037     -1.989      0.047      -0.147      -0.001
# mnth_Oct         -0.0142      0.036     -0.397      0.692      -0.085       0.056
# mnth_Sep          0.0634      0.032      1.995      0.047       0.001       0.126
# weekday_Mon      -0.0228      0.015     -1.530      0.127      -0.052       0.007
# weekday_Sar      -0.1006      0.071     -1.420      0.156      -0.240       0.039
# weekday_Sun      -0.0872      0.071     -1.230      0.219      -0.226       0.052
# weekday_Thurs    -0.0053      0.015     -0.360      0.719      -0.034       0.024
# weekday_Tues     -0.0351      0.015     -2.404      0.017      -0.064      -0.006
# weekday_Wed      -0.0201      0.015     -1.361      0.174      -0.049       0.009
# weathersit_B     -0.0474      0.011     -4.459      0.000      -0.068      -0.027
# weathersit_C     -0.2072      0.026     -8.069      0.000      -0.258      -0.157
# ==============================================================================
# Omnibus:                       86.672   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              249.174
# Skew:                          -0.814   Prob(JB):                     7.81e-55
# Kurtosis:                       6.013   Cond. No.                         71.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from sklearn.feature_selection import RFE

# %%
lm= LinearRegression()
rfe1 = RFE(estimator=lm, n_features_to_select=15)

rfe1.fit(x_train,y_train)
print(rfe1.support_)
print(rfe1.ranking_)
# Out:
# [ True  True  True  True  True  True  True  True  True False False False
#  False False False False False  True False  True False  True  True False
#  False False  True  True]
# [ 1  1  1  1  1  1  1  1  1 14  2  5  3  4  8 13  7  1 11  1  9  1  1 12
#   6 10  1  1]

# %%
col1=x_train.columns[rfe1.support_]

# %%
col1
# Out:
# Index(['yr', 'holiday', 'workingday', 'temp', 'hum', 'windspeed',
#        'season_fall', 'season_spring', 'season_summer', 'mnth_Novem',
#        'mnth_Sep', 'weekday_Sar', 'weekday_Sun', 'weathersit_B',
#        'weathersit_C'],
#       dtype='object')

# %%
x_train_rfe1=x_train[col1]
x_train_rfe1= sm.add_constant(x_train_rfe1)
lm1= sm.OLS(y_train,x_train_rfe1).fit()
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.848
# Model:                            OLS   Adj. R-squared:                  0.843
# Method:                 Least Squares   F-statistic:                     183.7
# Date:                Sun, 05 May 2024   Prob (F-statistic):          6.06e-191
# Time:                        12:48:40   Log-Likelihood:                 521.58
# No. Observations:                 510   AIC:                            -1011.
# Df Residuals:                     494   BIC:                            -943.4
# Df Model:                          15
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.4878      0.077      6.301      0.000       0.336       0.640
# yr                0.2297      0.008     28.847      0.000       0.214       0.245
# holiday          -0.1286      0.065     -1.991      0.047      -0.255      -0.002
# workingday       -0.0803      0.071     -1.137      0.256      -0.219       0.058
# temp              0.5267      0.033     15.904      0.000       0.462       0.592
# hum              -0.2149      0.037     -5.766      0.000      -0.288      -0.142
# windspeed        -0.1855      0.026     -7.258      0.000      -0.236      -0.135
# season_fall      -0.1221      0.017     -7.028      0.000      -0.156      -0.088
# season_spring    -0.1743      0.014    -12.466      0.000      -0.202      -0.147
# season_summer    -0.0576      0.014     -4.230      0.000      -0.084      -0.031
# mnth_Novem       -0.0298      0.017     -1.743      0.082      -0.063       0.004
# mnth_Sep          0.0806      0.017      4.630      0.000       0.046       0.115
# weekday_Sar      -0.0671      0.070     -0.952      0.342      -0.205       0.071
# weekday_Sun      -0.0513      0.070     -0.729      0.467      -0.190       0.087
# weathersit_B     -0.0434      0.011     -4.066      0.000      -0.064      -0.022
# weathersit_C     -0.1989      0.026     -7.761      0.000      -0.249      -0.149
# ==============================================================================
# Omnibus:                       72.994   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              171.142
# Skew:                          -0.753   Prob(JB):                     6.87e-38
# Kurtosis:                       5.405   Cond. No.                         67.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
a= x_train_rfe1.drop('const',axis=1)

# %%
# Evaluating VIF's
vlf= pd.DataFrame()
vlf['features']=a.columns
vlf['VIF']=[variance_inflation_factor(a.values,i)for i in range(a.shape[1])]
vlf['VIF']=round(vlf['VIF'],2)
vlf=vlf.sort_values(by="VIF",ascending=False)
vlf
# Out:
#          features    VIF
# 4             hum  36.10
# 2      workingday  33.20
# 3            temp  25.13
# 11    weekday_Sar   7.52
# 12    weekday_Sun   6.65
# 5       windspeed   5.38
# 6     season_fall   4.90
# 8   season_summer   3.07
# 7   season_spring   2.98
# 13   weathersit_B   2.50
# 0              yr   1.96
# 1         holiday   1.86
# 9      mnth_Novem   1.65
# 14   weathersit_C   1.33
# 10       mnth_Sep   1.28

# %%
lm= LinearRegression()
rfe2 = RFE(estimator=lm, n_features_to_select=7)

rfe2.fit(x_train,y_train)
print(rfe2.support_)
print(rfe2.ranking_)
# Out:
# [ True False False  True  True  True False  True False False False False
#  False False False False False False False  True False False False False
#  False False False  True]
# [ 1  3  4  1  1  1  2  1  7 22 10 13 11 12 16 21 15  9 19  1 17  5  6 20
#  14 18  8  1]

# %%
col2=x_train.columns[rfe2.support_]
x_train_rfe2=x_train[col2]
x_train_rfe2= sm.add_constant(x_train_rfe2)
lm2= sm.OLS(y_train,x_train_rfe2).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.823
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     333.2
# Date:                Sun, 05 May 2024   Prob (F-statistic):          3.92e-184
# Time:                        12:49:44   Log-Likelihood:                 482.59
# No. Observations:                 510   AIC:                            -949.2
# Df Residuals:                     502   BIC:                            -915.3
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.4569      0.028     16.240      0.000       0.402       0.512
# yr                0.2327      0.008     27.510      0.000       0.216       0.249
# temp              0.3881      0.023     16.656      0.000       0.342       0.434
# hum              -0.2633      0.031     -8.444      0.000      -0.325      -0.202
# windspeed        -0.1965      0.027     -7.370      0.000      -0.249      -0.144
# season_spring    -0.1628      0.012    -13.152      0.000      -0.187      -0.138
# mnth_Sep          0.0567      0.018      3.227      0.001       0.022       0.091
# weathersit_C     -0.1659      0.026     -6.495      0.000      -0.216      -0.116
# ==============================================================================
# Omnibus:                       49.169   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               96.838
# Skew:                          -0.573   Prob(JB):                     9.37e-22
# Kurtosis:                       4.800   Cond. No.                         15.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y_train_cnt=lm2.predict(x_train_rfe2)

# %%
fig=plt.figure()
sns.distplot((y_train,y_train_cnt),bins=20)
# Out:
# <Axes: ylabel='Density'>

# %%
df_test[va]=scaler.transform(df_test[va])
y_test=df_test.pop('cnt')
x_test=df_test.drop(["casual","registered"],axis=1)

# %%
x_test.head()
# Out:
#      yr  holiday  workingday      temp       hum  windspeed  season_fall  \
# 333   0        0           1  0.341207  0.632030   0.488582            0
# 203   0        0           1  1.013904  0.515242   0.185727            1
# 279   0        0           0  0.579699  0.705024  -0.049804            0
# 483   1        0           1  0.512322  0.604980   0.154750            0
# 267   0        0           1  0.737981  0.870760   0.010767            0
#
#      season_spring  season_summer  mnth_Aug  ...  mnth_Oct  mnth_Sep  \
# 333              0              0         0  ...         0         0
# 203              0              0         0  ...         0         0
# 279              0              0         0  ...         1         0
# 483              0              1         0  ...         0         0
# 267              0              0         0  ...         0         1
#
#      weekday_Mon  weekday_Sar  weekday_Sun  weekday_Thurs  weekday_Tues  \
# 333            0            0            0              0             0
# 203            1            0            0              0             0
# 279            0            0            1              0             0
# 483            1            0            0              0             0
# 267            0            0            0              0             1
#
#      weekday_Wed  weathersit_B  weathersit_C
# 333            0             0             0
# 203            0             0             0
# 279            0             0             0
# 483            0             0             0
# 267            0             1             0
#
# [5 rows x 28 columns]

# %%
c= x_train_rfe2.drop('const',axis=1)

# %%
cols2=c.columns

# %%
x_test_rfe2= x_test[col2]
x_test_rfe2=sm.add_constant(x_test_rfe2)
x_test_rfe2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 219 entries, 333 to 43
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   const          219 non-null    float64
#  1   yr             219 non-null    int64
#  2   temp           219 non-null    float64
#  3   hum            219 non-null    float64
#  4   windspeed      219 non-null    float64
#  5   season_spring  219 non-null    int64
#  6   mnth_Sep       219 non-null    int64
#  7   weathersit_C   219 non-null    int64
# dtypes: float64(4), int64(4)
# memory usage: 15.4 KB

# %%
y_predic= lm2.predict(x_test_rfe2)
plt.figure()
plt.scatter(y_test,y_predic)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_predic)
# Out:
# 0.7725430435577938

# %%
plt.figure(figsize=(8,5))
sns.heatmap(dataset[col2].corr(),cmap="YlGnBu",annot=True)
plt.show()
